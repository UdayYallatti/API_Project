# %%
from streamlit import secrets
api_key = secrets["API_KEY"]

# %%
import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"datatype":"json","keywords":"Tesla","function":"SYMBOL_SEARCH"}

headers = {
	"x-rapidapi-key": api_key,
	"x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'bestMatches': [{'1. symbol': '0R0X.LON', '2. name': 'Tesla', '3. type': 'Equity', '4. region': 'United Kingdom', '5. marketOpen': '08:00', '6. marketClose': '16:30', '7. timezone': 'UTC+01', '8. currency': 'LSE', '9. matchScore': '1.0000'}, {'1. symbol': 'TSLA', '2. name': 'Tesla Inc', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.8889'}, {'1. symbol': 'TL0.DEX', '2. name': 'Tesla Inc', '3. type': 'Equity', '4. region': 'XETRA', '5. marketOpen': '08:00', '6. marketClose': '20:00', '7. timezone': 'UTC+02', '8. currency': 'EUR', '9. matchScore': '0.7143'}, {'1. symbol': 'TL0.FRK', '2. name': 'Tesla Inc', '3. type': 'Equity', '4. region': 'Frankfurt', '5. marketOpen': '08:00', '6. marketClose': '20:00', '7. timezone': 'UTC+02', '8. currency': 'EUR', '9. matchScore': '0.7143'}, {'1. symbol': 'TSLA34.SAO', '2. name': 'Tesla Inc', '3. type': 'Equity', '4. region': 'Brazil/Sao Paolo', '5. marketOpen': '10:00', '6. marketClose': '17:30', '7. timezone': 'UTC-03', '8. currency': 'BRL', '9. matchScore': '0.7143'}, {'1. symbol': 'TSLA.TRT', '2. name': 'Tesla CDR (CAD Hedged)', '3. type': 'Equity', '4. region': 'Toronto', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-05', '8. currency': 'CAD', '9. matchScore': '0.6667'}, {'1. symbol': 'TL01.FRK', '2. name': 'TESLA INC. CDR DL-001', '3. type': 'Equity', '4. region': 'Frankfurt', '5. marketOpen': '08:00', '6. marketClose': '20:00', '7. timezone': 'UTC+02', '8. currency': 'EUR', '9. matchScore': '0.3846'}]}

# %%
data = response.json()
data["bestMatches"]
# Out:
# [{'1. symbol': '0R0X.LON',
#   '2. name': 'Tesla',
#   '3. type': 'Equity',
#   '4. region': 'United Kingdom',
#   '5. marketOpen': '08:00',
#   '6. marketClose': '16:30',
#   '7. timezone': 'UTC+01',
#   '8. currency': 'LSE',
#   '9. matchScore': '1.0000'},
#  {'1. symbol': 'TSLA',
#   '2. name': 'Tesla Inc',
#   '3. type': 'Equity',
#   '4. region': 'United States',
#   '5. marketOpen': '09:30',
#   '6. marketClose': '16:00',
#   '7. timezone': 'UTC-04',
#   '8. currency': 'USD',
#   '9. matchScore': '0.8889'},
#  {'1. symbol': 'TL0.DEX',
#   '2. name': 'Tesla Inc',
#   '3. type': 'Equity',
#   '4. region': 'XETRA',
#   '5. marketOpen': '08:00',
#   '6. marketClose': '20:00',
#   '7. timezone': 'UTC+02',
#   '8. currency': 'EUR',
#   '9. matchScore': '0.7143'},
#  {'1. symbol': 'TL0.FRK',
#   '2. name': 'Tesla Inc',
#   '3. type': 'Equity',
#   '4. region': 'Frankfurt',
#   '5. marketOpen': '08:00',
#   '6. marketClose': '20:00',
#   '7. timezone': 'UTC+02',
#   '8. currency': 'EUR',
#   '9. matchScore': '0.7143'},
#  {'1. symbol': 'TSLA34.SAO',
#   '2. name': 'Tesla Inc',
#   '3. type': 'Equity',
#   '4. region': 'Brazil/Sao Paolo',
#   '5. marketOpen': '10:00',
#   '6. marketClose': '17:30',
#   '7. timezone': 'UTC-03',
#   '8. currency': 'BRL',
#   '9. matchScore': '0.7143'},
#  {'1. symbol': 'TSLA.TRT',
#   '2. name': 'Tesla CDR (CAD Hedged)',
#   '3. type': 'Equity',
#   '4. region': 'Toronto',
#   '5. marketOpen': '09:30',
#   '6. marketClose': '16:00',
#   '7. timezone': 'UTC-05',
#   '8. currency': 'CAD',
#   '9. matchScore': '0.6667'},
#  {'1. symbol': 'TL01.FRK',
#   '2. name': 'TESLA INC. CDR DL-001',
#   '3. type': 'Equity',
#   '4. region': 'Frankfurt',
#   '5. marketOpen': '08:00',
#   '6. marketClose': '20:00',
#   '7. timezone': 'UTC+02',
#   '8. currency': 'EUR',
#   '9. matchScore': '0.3846'}]

# %%
import pandas as pd
df = pd.DataFrame(data["bestMatches"])
df.head()
# Out:
#     1. symbol    2. name 3. type         4. region 5. marketOpen  \
# 0    0R0X.LON      Tesla  Equity    United Kingdom         08:00
# 1        TSLA  Tesla Inc  Equity     United States         09:30
# 2     TL0.DEX  Tesla Inc  Equity             XETRA         08:00
# 3     TL0.FRK  Tesla Inc  Equity         Frankfurt         08:00
# 4  TSLA34.SAO  Tesla Inc  Equity  Brazil/Sao Paolo         10:00
#
#   6. marketClose 7. timezone 8. currency 9. matchScore
# 0          16:30      UTC+01         LSE        1.0000
# 1          16:00      UTC-04         USD        0.8889
# 2          20:00      UTC+02         EUR        0.7143
# 3          20:00      UTC+02         EUR        0.7143
# 4          17:30      UTC-03         BRL        0.7143

# %%
import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"function":"TIME_SERIES_DAILY","symbol":"TSLA","outputsize":"compact","datatype":"json"}

headers = {
	"x-rapidapi-key": api_key,
	"x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'TSLA', '3. Last Refreshed': '2026-01-20', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2026-01-20': {'1. open': '429.3600', '2. high': '430.7250', '3. low': '417.4400', '4. close': '419.2500', '5. volume': '62208186'}, '2026-01-16': {'1. open': '439.5000', '2. high': '447.2500', '3. low': '435.2601', '4. close': '437.5000', '5. volume': '60220551'}, '2026-01-15': {'1. open': '441.1250', '2. high': '445.3600', '3. low': '437.6500', '4. close': '438.5700', '5. volume': '49465813'}, '2026-01-14': {'1. open': '442.8100', '2. high': '443.9100', '3. low': '434.2200', '4. close': '439.2000', '5. volume': '57259500'}, '2026-01-13': {'1. open': '450.2000', '2. high': '451.8100', '3. low': '443.9500', '4. close': '447.2000', '5. volume': '53719214'}, '2026-01-12': {'1. open': '441.2250', '2. high': '454.3000', '3. low': '438.0000', '4. close': '448.9600', '5. volume': '61649627'}, '2026-01-09': {'1. open': '435.9450', '2. high': '449.0500', '3. low': '430.3900', '4. close': '445.0100', '5. volume': '67331456'}, '2026-01-08': {'1. open': '427.8900', '2. high': '436.8900', '3. low': '424.3650', '4. close': '435.8000', '5. volume': '57041094'}, '2026-01-07': {'1. open': '435.9000', '2. high': '438.3700', '3. low': '431.2900', '4. close': '431.4100', '5. volume': '59828790'}, '2026-01-06': {'1. open': '446.3800', '2. high': '448.2500', '3. low': '428.7800', '4. close': '432.9600', '5. volume': '89093758'}, '2026-01-05': {'1. open': '447.9900', '2. high': '457.5499', '3. low': '444.5700', '4. close': '451.6700', '5. volume': '67940839'}, '2026-01-02': {'1. open': '457.8000', '2. high': '458.3400', '3. low': '435.3000', '4. close': '438.0700', '5. volume': '85535406'}, '2025-12-31': {'1. open': '456.1000', '2. high': '456.5500', '3. low': '449.3000', '4. close': '449.7200', '5. volume': '49077961'}, '2025-12-30': {'1. open': '461.0900', '2. high': '463.1200', '3. low': '453.8300', '4. close': '454.4300', '5. volume': '59238464'}, '2025-12-29': {'1. open': '469.0000', '2. high': '469.4000', '3. low': '459.0000', '4. close': '459.6400', '5. volume': '66263033'}, '2025-12-26': {'1. open': '485.2300', '2. high': '489.0900', '3. low': '473.8200', '4. close': '475.1900', '5. volume': '58780659'}, '2025-12-24': {'1. open': '488.4800', '2. high': '490.9000', '3. low': '476.8000', '4. close': '485.4000', '5. volume': '41285429'}, '2025-12-23': {'1. open': '489.3950', '2. high': '491.9700', '3. low': '482.8400', '4. close': '485.5600', '5. volume': '58223633'}, '2025-12-22': {'1. open': '489.8800', '2. high': '498.8300', '3. low': '485.3300', '4. close': '488.7300', '5. volume': '86916066'}, '2025-12-19': {'1. open': '488.1200', '2. high': '490.4900', '3. low': '474.7200', '4. close': '481.2000', '5. volume': '103305424'}, '2025-12-18': {'1. open': '478.1600', '2. high': '490.8600', '3. low': '473.1200', '4. close': '483.3700', '5. volume': '95168446'}, '2025-12-17': {'1. open': '488.2200', '2. high': '495.2799', '3. low': '466.2000', '4. close': '467.2600', '5. volume': '106490405'}, '2025-12-16': {'1. open': '472.2100', '2. high': '491.5000', '3. low': '465.8300', '4. close': '489.8800', '5. volume': '107608075'}, '2025-12-15': {'1. open': '469.4400', '2. high': '481.7694', '3. low': '467.6600', '4. close': '475.3100', '5. volume': '114542204'}, '2025-12-12': {'1. open': '448.0900', '2. high': '463.0100', '3. low': '441.6700', '4. close': '458.9600', '5. volume': '95656749'}, '2025-12-11': {'1. open': '448.9450', '2. high': '449.2699', '3. low': '440.3300', '4. close': '446.8900', '5. volume': '55979492'}, '2025-12-10': {'1. open': '446.0650', '2. high': '456.8800', '3. low': '443.6100', '4. close': '451.4500', '5. volume': '63257475'}, '2025-12-09': {'1. open': '437.5400', '2. high': '452.3900', '3. low': '435.7000', '4. close': '445.1700', '5. volume': '62014951'}, '2025-12-08': {'1. open': '447.4450', '2. high ...

# %%
data = response.json()
data.keys()
# Out:
# dict_keys(['Meta Data', 'Time Series (Daily)'])

# %%
daily_data = data["Time Series (Daily)"]
daily_data
# Out:
# {'2026-01-20': {'1. open': '429.3600',
#   '2. high': '430.7250',
#   '3. low': '417.4400',
#   '4. close': '419.2500',
#   '5. volume': '62208186'},
#  '2026-01-16': {'1. open': '439.5000',
#   '2. high': '447.2500',
#   '3. low': '435.2601',
#   '4. close': '437.5000',
#   '5. volume': '60220551'},
#  '2026-01-15': {'1. open': '441.1250',
#   '2. high': '445.3600',
#   '3. low': '437.6500',
#   '4. close': '438.5700',
#   '5. volume': '49465813'},
#  '2026-01-14': {'1. open': '442.8100',
#   '2. high': '443.9100',
#   '3. low': '434.2200',
#   '4. close': '439.2000',
#   '5. volume': '57259500'},
#  '2026-01-13': {'1. open': '450.2000',
#   '2. high': '451.8100',
#   '3. low': '443.9500',
#   '4. close': '447.2000',
#   '5. volume': '53719214'},
#  '2026-01-12': {'1. open': '441.2250',
#   '2. high': '454.3000',
#   '3. low': '438.0000',
#   '4. close': '448.9600',
#   '5. volume': '61649627'},
#  '2026-01-09': {'1. open': '435.9450',
#   '2. high': '449.0500',
#   '3. low': '430.3900',
#   '4. close': '445.0100',
#   '5. volume': '67331456'},
#  '2026-01-08': {'1. open': '427.8900',
#   '2. high': '436.8900',
#   '3. low': '424.3650',
#   '4. close': '435.8000',
#   '5. volume': '57041094'},
#  '2026-01-07': {'1. open': '435.9000',
#   '2. high': '438.3700',
#   '3. low': '431.2900',
#   '4. close': '431.4100',
#   '5. volume': '59828790'},
#  '2026-01-06': {'1. open': '446.3800',
#   '2. high': '448.2500',
#   '3. low': '428.7800',
#   '4. close': '432.9600',
#   '5. volume': '89093758'},
#  '2026-01-05': {'1. open': '447.9900',
#   '2. high': '457.5499',
#   '3. low': '444.5700',
#   '4. close': '451.6700',
#   '5. volume': '67940839'},
#  '2026-01-02': {'1. open': '457.8000',
#   '2. high': '458.3400',
#   '3. low': '435.3000',
#   '4. close': '438.0700',
#   '5. volume': '85535406'},
#  '2025-12-31': {'1. open': '456.1000',
#   '2. high': '456.5500',
#   '3. low': '449.3000',
#   '4. close': '449.7200',
#   '5. volume': '49077961'},
#  '2025-12-30': {'1. open': '461.0900',
#   '2. high': '463.1200',
#   '3. low': '453.8300',
#   '4. close': '454.4300',
#   '5. volume': '59238464'},
#  '2025-12-29': {'1. open': '469.0000',
#   '2. high': '469.4000',
#   '3. low': '459.0000',
#   '4. close': '459.6400',
#   '5. volume': '66263033'},
#  '2025-12-26': {'1. open': '485.2300',
#   '2. high': '489.0900',
#   '3. low': '473.8200',
#   '4. close': '475.1900',
#   '5. volume': '58780659'},
#  '2025-12-24': {'1. open': '488.4800',
#   '2. high': '490.9000',
#   '3. low': '476.8000',
#   '4. close': '485.4000',
#   '5. volume': '41285429'},
#  '2025-12-23': {'1. open': '489.3950',
#   '2. high': '491.9700',
#   '3. low': '482.8400',
#   '4. close': '485.5600',
#   '5. volume': '58223633'},
#  '2025-12-22': {'1. open': '489.8800',
#   '2. high': '498.8300',
#   '3. low': '485.3300',
#   '4. close': '488.7300',
#   '5. volume': '86916066'},
#  '2025-12-19': {'1. open': '488.1200',
#   '2. high': '490.4900',
#   '3. low': '474.7200',
#   '4. close': '481.2000',
#   '5. volume': '103305424'},
#  '2025-12-18': {'1. open': '478.1600',
#   '2. high': '490.8600',
#   '3. low': '473.1200',
#   '4. close': '483.3700',
#   '5. volume': '95168446'},
#  '2025-12-17': {'1. open': '488.2200',
#   '2. high': '495.2799',
#   '3. low': '466.2000',
#   '4. close': '467.2600',
#   '5. volume': '106490405'},
#  '2025-12-16': {'1. open': '472.2100',
#   '2. high': '491.5000',
#   '3. low': '465.8300',
#   '4. close': '489.8800',
#   '5. volume': '107608075'},
#  '2025-12-15': {'1. open': '469.4400',
#   '2. high': '481.7694',
#   '3. low': '467.6600',
#   '4. close': '475.3100',
#   '5. volume': '114542204'},
#  '2025-12-12': {'1. open': '448.0900',
#   '2. high': '463.0100',
#   '3. low': '441.6700',
#   '4. close': '458.9600',
#   '5. volume': '95656749'},
#  '2025-12-11': {'1. open': '448.9450',
#   '2. high': '449.2699',
#   '3. low': '440.3300',
#   '4. close': '446.8900',
#   '5. volume': '55979492'},
#  '2025-12-10': {'1. open': '446.0650',
#   '2. high': '456.8800',
#   '3. low': '443.6100',
#   '4. close': '451.4500',
#   '5. volume': '63257475'},
#  '2025-12-09': {'1. open': '437.5400',
#   '2. high': '452.3900',
#   '3. low': '435.7000',
#   '4. close': '445.1700',
#   '5. volume': '62014951'},
#  '2025-12-08': {'1. open': '447.4450',
#   '2. high': '449.7463',
#   '3. low': '435.2500',
#   '4. close': '439.5800',
#   '5. volume': '68386756'},
#  '2025-12-05': {'1. open': '453.0300',
#   '2. high': '458.8700',
#   '3. low': '451.6600',
#   '4. close': '455.0000',
#   '5. volume': '56427522'},
#  '2025-12-04': {'1. open': '449.9400',
#   '2. high': '454.6300',
#   '3. low': '445.3900',
#   '4. close': '454.5300',
#   '5. volume': '71906488'},
#  '2025-12-03': {'1. open': '432.1000',
#   '2. high': '447.9200',
#   '3. low': '431.1100',
#   '4. close': '446.7400',
#   '5. volume': '87482964'},
#  '2025-12-02': {'1. open': '430.8100',
#   '2. high': '436.8000',
#   '3. low': '422.1200',
#   '4. close': '429.2400',
#   '5. volume': '69336626'},
#  '2025-12-01': {'1. open': '425.3200',
#   '2. high': '433.6599',
#   '3. low': '425.2900',
#   '4. close': '430.1400',
#   '5. volume': '57463552'},
#  '2025-11-28': {'1. open': '426.5900',
#   '2. high': '432.9300',
#   '3. low': '426.2000',
#   '4. close': '430.1700',
#   '5. volume': '36252861'},
#  '2025-11-26': {'1. open': '423.9500',
#   '2. high': '426.9400',
#   '3. low': '416.8900',
#   '4. close': '426.5800',
#   '5. volume': '63462996'},
#  '2025-11-25': {'1. open': '414.4200',
#   '2. high': '420.4800',
#   '3. low': '405.9500',
#   '4. close': '419.4000',
#   '5. volume': '71915624'},
#  '2025-11-24': {'1. open': '402.1700',
#   '2. high': '421.7200',
#   '3. low': '401.0900',
#   '4. close': '417.7800',
#   '5. volume': '96806374'},
#  '2025-11-21': {'1. open': '402.3200',
#   '2. high': '402.8000',
#   '3. low': '383.7600',
#   '4. close': '391.0900',
#   '5. volume': '100460633'},
#  '2025-11-20': {'1. open': '414.6300',
#   '2. high': '428.9400',
#   '3. low': '394.7400',
#   '4. close': '395.2300',
#   '5. volume': '113548827'},
#  '2025-11-19': {'1. open': '406.1800',
#   '2. high': '411.7800',
#   '3. low': '398.5000',
#   '4. close': '403.9900',
#   '5. volume': '72047704'},
#  '2025-11-18': {'1. open': '405.3800',
#   '2. high': '408.9000',
#   '3. low': '393.7100',
#   '4. close': '401.2500',
#   '5. volume': '80688637'},
#  '2025-11-17': {'1. open': '398.7400',
#   '2. high': '423.9600',
#   '3. low': '398.7400',
#   '4. close': '408.9200',
#   '5. volume': '102214259'},
#  '2025-11-14': {'1. open': '386.3000',
#   '2. high': '412.1900',
#   '3. low': '382.7800',
#   '4. close': '404.3500',
#   '5. volume': '105506682'},
#  '2025-11-13': {'1. open': '423.1300',
#   '2. high': '424.5000',
#   '3. low': '396.3400',
#   '4. close': '401.9900',
#   '5. volume': '118948032'},
#  '2025-11-12': {'1. open': '442.1500',
#   '2. high': '442.3290',
#   '3. low': '426.5600',
#   '4. close': '430.6000',
#   '5. volume': '58513520'},
#  '2025-11-11': {'1. open': '439.4000',
#   '2. high': '442.4900',
#   '3. low': '432.3600',
#   '4. close': '439.6200',
#   '5. volume': '60533237'},
#  '2025-11-10': {'1. open': '439.6000',
#   '2. high': '449.6715',
#   '3. low': '433.3600',
#   '4. close': '445.2300',
#   '5. volume': '76515907'},
#  '2025-11-07': {'1. open': '437.9200',
#   '2. high': '439.3600',
#   '3. low': '421.8800',
#   '4. close': '429.5200',
#   '5. volume': '103471495'},
#  '2025-11-06': {'1. open': '461.9600',
#   '2. high': '467.4500',
#   '3. low': '435.0900',
#   '4. close': '445.9100',
#   '5. volume': '109622907'},
#  '2025-11-05': {'1. open': '452.0500',
#   '2. high': '466.3299',
#   '3. low': '440.7100',
#   '4. close': '462.0700',
#   '5. volume': '84911911'},
#  '2025-11-04': {'1. open': '454.4600',
#   '2. high': '460.2200',
#   '3. low': '443.6000',
#   '4. close': '444.2600',
#   '5. volume': '87756644'},
#  '2025-11-03': {'1. open': '455.9900',
#   '2. high': '474.0700',
#   '3. low': '453.8000',
#   '4. close': '468.3700',
#   '5. volume': '84595244'},
#  '2025-10-31': {'1. open': '446.7500',
#   '2. high': '458.0000',
#   '3. low': '443.6855',
#   '4. close': '456.5600',
#   '5. volume': '83135787'},
#  '2025-10-30': {'1. open': '451.0500',
#   '2. high': '455.0607',
#   '3. low': '439.6100',
#   '4. close': '440.1000',
#   '5. volume': '72447938'},
#  '2025-10-29': {'1. open': '462.5000',
#   '2. high': '465.7000',
#   '3. low': '452.6500',
#   '4. close': '461.5100',
#   '5. volume': '67983544'},
#  '2025-10-28': {'1. open': '454.7750',
#   '2. high': '467.0000',
#   '3. low': '451.6000',
#   '4. close': '460.5500',
#   '5. volume': '80185667'},
#  '2025-10-27': {'1. open': '439.9800',
#   '2. high': '460.1600',
#   '3. low': '438.6900',
#   '4. close': '452.4200',
#   '5. volume': '105867547'},
#  '2025-10-24': {'1. open': '446.8300',
#   '2. high': '451.6800',
#   '3. low': '430.1700',
#   '4. close': '433.7200',
#   '5. volume': '94727774'},
#  '2025-10-23': {'1. open': '420.0000',
#   '2. high': '449.3999',
#   '3. low': '413.9000',
#   '4. close': '448.9800',
#   '5. volume': '126709833'},
#  '2025-10-22': {'1. open': '443.4500',
#   '2. high': '445.5390',
#   '3. low': '429.0000',
#   '4. close': '438.9700',
#   '5. volume': '84023458'},
#  '2025-10-21': {'1. open': '445.7550',
#   '2. high': '449.3000',
#   '3. low': '442.0500',
#   '4. close': '442.6000',
#   '5. volume': '54412169'},
#  '2025-10-20': {'1. open': '443.8650',
#   '2. high': '449.8000',
#   '3. low': '440.6100',
#   '4. close': '447.4300',
#   '5. volume': '63718971'},
#  '2025-10-17': {'1. open': '425.5000',
#   '2. high': '441.4558',
#   '3. low': '423.6000',
#   '4. close': '439.3100',
#   '5. volume': '89331578'},
#  '2025-10-16': {'1. open': '434.7300',
#   '2. high': '439.3500',
#   '3. low': '421.3101',
#   '4. close': '428.7500',
#   '5. volume': '77189889'},
#  '2025-10-15': {'1. open': '434.9000',
#   '2. high': '440.5100',
#   '3. low': '426.3301',
#   '4. close': '435.1500',
#   '5. volume': '71558185'},
#  '2025-10-14': {'1. open': '426.7900',
#   '2. high': '434.2000',
#   '3. low': '417.8600',
#   '4. close': '429.2400',
#   '5. volume': '72669438'},
#  '2025-10-13': {'1. open': '423.5300',
#   '2. high': '436.8900',
#   '3. low': '419.7000',
#   '4. close': '435.9000',
#   '5. volume': '79552785'},
#  '2025-10-10': {'1. open': '436.5400',
#   '2. high': '443.1300',
#   '3. low': '411.4500',
#   '4. close': '413.4900',
#   '5. volume': '112107870'},
#  '2025-10-09': {'1. open': '431.8100',
#   '2. high': '436.3500',
#   '3. low': '426.1800',
#   '4. close': '435.5400',
#   '5. volume': '69339928'},
#  '2025-10-08': {'1. open': '437.5700',
#   '2. high': '441.3300',
#   '3. low': '425.2300',
#   '4. close': '438.6900',
#   '5. volume': '71192128'},
#  '2025-10-07': {'1. open': '447.8200',
#   '2. high': '452.6800',
#   '3. low': '432.4501',
#   '4. close': '433.0900',
#   '5. volume': '102296082'},
#  '2025-10-06': {'1. open': '440.7500',
#   '2. high': '453.5500',
#   '3. low': '436.6900',
#   '4. close': '453.2500',
#   '5. volume': '85324878'},
#  '2025-10-03': {'1. open': '443.2850',
#   '2. high': '446.7700',
#   '3. low': '416.5750',
#   '4. close': '429.8300',
#   '5. volume': '133188180'},
#  '2025-10-02': {'1. open': '470.5400',
#   '2. high': '470.7500',
#   '3. low': '435.5700',
#   '4. close': '436.0000',
#   '5. volume': '137008950'},
#  '2025-10-01': {'1. open': '443.8000',
#   '2. high': '462.2900',
#   '3. low': '440.7500',
#   '4. close': '459.4600',
#   '5. volume': '98122285'},
#  '2025-09-30': {'1. open': '441.5200',
#   '2. high': '445.0000',
#   '3. low': '433.1200',
#   '4. close': '444.7200',
#   '5. volume': '74357960'},
#  '2025-09-29': {'1. open': '444.3500',
#   '2. high': '450.9800',
#   '3. low': '439.5000',
#   '4. close': '443.2100',
#   '5. volume': '79491510'},
#  '2025-09-26': {'1. open': '428.3000',
#   '2. high': '440.4700',
#   '3. low': '421.0200',
#   '4. close': '440.4000',
#   '5. volume': '101628160'},
#  '2025-09-25': {'1. open': '435.2400',
#   '2. high': '435.3500',
#   '3. low': '419.0800',
#   '4. close': '423.3900',
#   '5. volume': '96746426'},
#  '2025-09-24': {'1. open': '429.8300',
#   '2. high': '444.2100',
#   '3. low': '429.0301',
#   '4. close': '442.7900',
#   '5. volume': '93133570'},
#  '2025-09-23': {'1. open': '439.8800',
#   '2. high': '440.9700',
#   '3. low': '423.7200',
#   '4. close': '425.8500',
#   '5. volume': '83422691'},
#  '2025-09-22': {'1. open': '431.1100',
#   '2. high': '444.9800',
#   '3. low': '429.1300',
#   '4. close': '434.2100',
#   '5. volume': '97108777'},
#  '2025-09-19': {'1. open': '421.8200',
#   '2. high': '429.4700',
#   '3. low': '421.7200',
#   '4. close': '426.0700',
#   '5. volume': '93131034'},
#  '2025-09-18': {'1. open': '428.8650',
#   '2. high': '432.2199',
#   '3. low': '416.5600',
#   '4. close': '416.8500',
#   '5. volume': '90454509'},
#  '2025-09-17': {'1. open': '415.7500',
#   '2. high': '428.3121',
#   '3. low': '409.6700',
#   '4. close': '425.8600',
#   '5. volume': '106133532'},
#  '2025-09-16': {'1. open': '414.4950',
#   '2. high': '423.2500',
#   '3. low': '411.4300',
#   '4. close': '421.6200',
#   '5. volume': '104285721'},
#  '2025-09-15': {'1. open': '423.1300',
#   '2. high': '425.7000',
#   '3. low': '402.4300',
#   '4. close': '410.0400',
#   '5. volume': '163823667'},
#  '2025-09-12': {'1. open': '370.9400',
#   '2. high': '396.6899',
#   '3. low': '370.2400',
#   '4. close': '395.9400',
#   '5. volume': '168156391'},
#  '2025-09-11': {'1. open': '350.1700',
#   '2. high': '368.9900',
#   '3. low': '347.6000',
#   '4. close': '368.8100',
#   '5. volume': '103756010'},
#  '2025-09-10': {'1. open': '350.5500',
#   '2. high': '356.3300',
#   '3. low': '346.0700',
#   '4. close': '347.7900',
#   '5. volume': '72121679'},
#  '2025-09-09': {'1. open': '348.4400',
#   '2. high': '350.7700',
#   '3. low': '343.8200',
#   '4. close': '346.9700',
#   '5. volume': '53815991'},
#  '2025-09-08': {'1. open': '354.6400',
#   '2. high': '358.4400',
#   '3. low': '344.8400',
#   '4. close': '346.4000',
#   '5. volume': '75208290'},
#  '2025-09-05': {'1. open': '348.0000',
#   '2. high': '355.8700',
#   '3. low': '344.6801',
#   '4. close': '350.8400',
#   '5. volume': '108989785'},
#  '2025-09-04': {'1. open': '336.1500',
#   '2. high': '338.8900',
#   '3. low': '331.4800',
#   '4. close': '338.5300',
#   '5. volume': '60711033'},
#  '2025-09-03': {'1. open': '335.2000',
#   '2. high': '343.3300',
#   '3. low': '328.5100',
#   '4. close': '334.0900',
#   '5. volume': '88238894'},
#  '2025-09-02': {'1. open': '328.2300',
#   '2. high': '333.3300',
#   '3. low': '325.6000',
#   '4. close': '329.3600',
#   '5. volume': '58391952'},
#  '2025-08-29': {'1. open': '347.2300',
#   '2. high': '348.7499',
#   '3. low': '331.7000',
#   '4. close': '333.8700',
#   '5. volume': '81145660'},
#  '2025-08-28': {'1. open': '350.9100',
#   '2. high': '353.5500',
#   '3. low': '340.2600',
#   '4. close': '345.9800',
#   '5. volume': '67903224'},
#  '2025-08-27': {'1. open': '351.9400',
#   '2. high': '355.3900',
#   '3. low': '349.1560',
#   '4. close': '349.6000',
#   '5. volume': '65519012'}}

# %%
df_daily = pd.DataFrame(daily_data).T
df_daily
# Out:
#              1. open   2. high    3. low  4. close 5. volume
# 2026-01-20  429.3600  430.7250  417.4400  419.2500  62208186
# 2026-01-16  439.5000  447.2500  435.2601  437.5000  60220551
# 2026-01-15  441.1250  445.3600  437.6500  438.5700  49465813
# 2026-01-14  442.8100  443.9100  434.2200  439.2000  57259500
# 2026-01-13  450.2000  451.8100  443.9500  447.2000  53719214
# ...              ...       ...       ...       ...       ...
# 2025-09-03  335.2000  343.3300  328.5100  334.0900  88238894
# 2025-09-02  328.2300  333.3300  325.6000  329.3600  58391952
# 2025-08-29  347.2300  348.7499  331.7000  333.8700  81145660
# 2025-08-28  350.9100  353.5500  340.2600  345.9800  67903224
# 2025-08-27  351.9400  355.3900  349.1560  349.6000  65519012
#
# [100 rows x 5 columns]

# %%
df_daily.dtypes
# Out:
# 1. open      object
# 2. high      object
# 3. low       object
# 4. close     object
# 5. volume    object
# dtype: object

# %%
df_daily = df_daily.astype(float)
df_daily.dtypes
# Out:
# 1. open      float64
# 2. high      float64
# 3. low       float64
# 4. close     float64
# 5. volume    float64
# dtype: object

# %%
df_daily.index = pd.to_datetime(df_daily.index)

# %%
df_daily
# Out:
#             1. open   2. high    3. low  4. close   5. volume
# 2026-01-20  429.360  430.7250  417.4400    419.25  62208186.0
# 2026-01-16  439.500  447.2500  435.2601    437.50  60220551.0
# 2026-01-15  441.125  445.3600  437.6500    438.57  49465813.0
# 2026-01-14  442.810  443.9100  434.2200    439.20  57259500.0
# 2026-01-13  450.200  451.8100  443.9500    447.20  53719214.0
# ...             ...       ...       ...       ...         ...
# 2025-09-03  335.200  343.3300  328.5100    334.09  88238894.0
# 2025-09-02  328.230  333.3300  325.6000    329.36  58391952.0
# 2025-08-29  347.230  348.7499  331.7000    333.87  81145660.0
# 2025-08-28  350.910  353.5500  340.2600    345.98  67903224.0
# 2025-08-27  351.940  355.3900  349.1560    349.60  65519012.0
#
# [100 rows x 5 columns]

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure(
    data = [
        go.Candlestick(
            x = df_daily.index,
            open= df_daily["1. open"],
            high= df_daily["2. high"],
            low= df_daily["3. low"],
            close= df_daily["4. close"]
        )
    ]
)

fig.show()

# %%
df_daily.to_csv("TSLA.csv")

# %%
df = pd.read_csv("TSLA.csv")
df.head()
# Out:
#    Unnamed: 0  1. open  2. high    3. low  4. close   5. volume
# 0  2026-01-20  429.360  430.725  417.4400    419.25  62208186.0
# 1  2026-01-16  439.500  447.250  435.2601    437.50  60220551.0
# 2  2026-01-15  441.125  445.360  437.6500    438.57  49465813.0
# 3  2026-01-14  442.810  443.910  434.2200    439.20  57259500.0
# 4  2026-01-13  450.200  451.810  443.9500    447.20  53719214.0

# %%
import requests
import pandas as pd
import plotly.graph_objects as go
import streamlit as st 


class StockAPI:
    def __init__(self):
        self.api_key = st.secrets["API_KEY"]
        self.headers = {
	        "x-rapidapi-key": self.api_key,
	        "x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
        }
        self.url = "https://alpha-vantage.p.rapidapi.com/query"

    def search_symbol(self, company: str):
        querystring = {"datatype":"json","keywords":company,"function":"SYMBOL_SEARCH"}

        response = requests.get(self.url, headers=self.headers, params=querystring)

        data = response.json()
        df = pd.DataFrame(data["bestMatches"])
        return df
    
    def get_daily_data(self, symbol:str):
        querystring = {"function":"TIME_SERIES_DAILY","symbol":symbol,"outputsize":"compact","datatype":"json"}
        response = requests.get(self.url, headers= self.headers, params=querystring)
        data = response.json()
        daily_df = pd.DataFrame(data["Time Series (Daily)"]).T
        daily_df = daily_df.astype(float)
        daily_df.index = pd.to_datetime(daily_df.index)
        return daily_df
    
    def plot_chart(self, df: pd.DataFrame):
        fig = go.Figure(
            data = [
                go.Candlestick(
                    x = df.index,
                    open = df["1. open"],
                    high = df["2. high"],
                    low = df["3. low"],
                    close = df["4. close"]
                )
            ]
        )
        fig.update_layout(width = 1000, height = 800)
        return fig

# %%
api = StockAPI()
type(api)
# Out:
# __main__.StockAPI

# %%
api.search_symbol(company="State Bank Of India")
# Out:
#   1. symbol                  2. name 3. type       4. region 5. marketOpen  \
# 0  SBIN.BSE      State Bank of India  Equity    India/Bombay         09:15
# 1     SBKFF      State Bank of India  Equity   United States         09:30
# 2   SID.FRK      State Bank of India  Equity       Frankfurt         08:00
# 3  SBID.LON  State Bank of India GDR  Equity  United Kingdom         08:00
#
#   6. marketClose 7. timezone 8. currency 9. matchScore
# 0          15:30     UTC+5.5         INR        1.0000
# 1          16:00      UTC-04         USD        1.0000
# 2          20:00      UTC+02         EUR        1.0000
# 3          16:30      UTC+01         USD        0.9048

# %%
df_sbi = api.get_daily_data(symbol = "SBIN.BSE")
df_sbi
# Out:
#             1. open  2. high   3. low  4. close  5. volume
# 2026-01-20  1044.80  1051.90  1033.30   1037.15   269961.0
# 2026-01-19  1036.00  1043.55  1033.65   1038.20   270858.0
# 2026-01-16  1029.10  1047.50  1028.45   1042.30   536890.0
# 2026-01-14  1028.50  1030.00  1021.00   1028.30   549159.0
# 2026-01-13  1019.40  1029.40  1015.70   1028.45  3578570.0
# ...             ...      ...      ...       ...        ...
# 2025-09-01   802.65   808.25   802.65    805.90   164286.0
# 2025-08-29   802.00   807.00   798.60    802.35   520632.0
# 2025-08-28   807.80   810.60   800.70    802.05   146716.0
# 2025-08-26   815.80   815.80   806.55    807.80   677825.0
# 2025-08-25   817.00   820.45   814.00    815.50   373280.0
#
# [100 rows x 5 columns]

# %%
df_sbi.to_csv("SBI.csv")

# %%
chart = api.plot_chart(df_sbi)
chart

# %%
api.search_symbol("Godrej")
# Out:
#         1. symbol                           2. name 3. type     4. region  \
# 0    GODREJCP.BSE     GODREJ CONSUMER PRODUCTS LTD.  Equity  India/Bombay
# 1   GODREJIND.BSE            GODREJ INDUSTRIES LTD.  Equity  India/Bombay
# 2  GODREJAGRO.BSE                Godrej Agrovet Ltd  Equity  India/Bombay
# 3  GODREJPROP.BSE             Godrej Properties Ltd  Equity  India/Bombay
# 4      540743.BSE            Godrej Agrovet Limited  Equity  India/Bombay
# 5      532424.BSE  Godrej Consumer Products Limited  Equity  India/Bombay
#
#   5. marketOpen 6. marketClose 7. timezone 8. currency 9. matchScore
# 0         09:15          15:30     UTC+5.5         INR        0.7059
# 1         09:15          15:30     UTC+5.5         INR        0.6667
# 2         09:15          15:30     UTC+5.5         INR        0.6316
# 3         09:15          15:30     UTC+5.5         INR        0.6316
# 4         09:15          15:30     UTC+5.5         INR        0.4286
# 5         09:15          15:30     UTC+5.5         INR        0.3158

# %%
api.get_daily_data("GODREJIND.BSE")
# Out:
#             1. open  2. high   3. low  4. close  5. volume
# 2026-01-20   997.45  1019.90   985.00   1001.15     8791.0
# 2026-01-19   997.65  1014.25   995.00    997.45     1290.0
# 2026-01-16  1003.00  1020.00   998.75   1015.85     1445.0
# 2026-01-15  1002.45  1002.45  1002.45   1002.45        0.0
# 2026-01-14   999.00  1012.45   990.80   1002.45     3266.0
# ...             ...      ...      ...       ...        ...
# 2025-09-08  1226.05  1226.05  1190.40   1207.00     1751.0
# 2025-09-05  1195.70  1205.00  1183.35   1198.20     2246.0
# 2025-09-04  1216.55  1218.90  1183.50   1195.95     2893.0
# 2025-09-03  1194.95  1206.65  1187.55   1200.60     3258.0
# 2025-09-02  1226.95  1226.95  1190.50   1198.75     5859.0
#
# [100 rows x 5 columns]

# %%
df_godrej = api.get_daily_data("GODREJIND.BSE")
df_godrej
# Out:
#             1. open  2. high   3. low  4. close  5. volume
# 2026-01-20   997.45  1019.90   985.00   1001.15     8791.0
# 2026-01-19   997.65  1014.25   995.00    997.45     1290.0
# 2026-01-16  1003.00  1020.00   998.75   1015.85     1445.0
# 2026-01-15  1002.45  1002.45  1002.45   1002.45        0.0
# 2026-01-14   999.00  1012.45   990.80   1002.45     3266.0
# ...             ...      ...      ...       ...        ...
# 2025-09-08  1226.05  1226.05  1190.40   1207.00     1751.0
# 2025-09-05  1195.70  1205.00  1183.35   1198.20     2246.0
# 2025-09-04  1216.55  1218.90  1183.50   1195.95     2893.0
# 2025-09-03  1194.95  1206.65  1187.55   1200.60     3258.0
# 2025-09-02  1226.95  1226.95  1190.50   1198.75     5859.0
#
# [100 rows x 5 columns]

# %%
df_godrej.to_csv("GODREJ.csv")

# %%
api.plot_chart(df_godrej)
